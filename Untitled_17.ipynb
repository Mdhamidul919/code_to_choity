# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.optimizers import Adagrad

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2

# %%
base_dir = r"C:\Users\ASUS\Desktop\All 4-1\thesis_ex\mango_leaf_and_buds_augmented"
#CATAGORIES= ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
IMAGE_SIZE = 124
BATCH_SIZE = 32

#PREprocessing

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range= 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    validation_split = 0.1
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale= 1./255,
    validation_split= 0.1
)

train_datagen = train_datagen.flow_from_directory(
    base_dir,
    target_size= (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE,
    subset = 'training'
)

test_datagen = test_datagen.flow_from_directory(
    base_dir,
    target_size= (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE,
    subset = 'validation'
)
# Out:
# Found 9720 images belonging to 4 classes.
# Found 1080 images belonging to 4 classes.

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(filters = 128, padding = 'same', strides = 2, kernel_size = 3, activation = 'relu', input_shape=( 124,124,3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size= 2,strides = 2))

model.add(tf.keras.layers.Conv2D(filters = 64, padding = 'same', strides = 2, kernel_size = 3, activation = 'relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size= 2,strides = 2))

model.add(tf.keras.layers.Conv2D(filters = 64, padding = 'same', strides = 2, kernel_size = 3, activation = 'relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size= 2,strides = 2))


model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(4, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)                   │ (None, 62, 62, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_17 (MaxPooling2D)      │ (None, 31, 31, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 16, 16, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 4, 4, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 115,332 (450.52 KB)
#  Trainable params: 115,332 (450.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),loss = 'categorical_crossentropy',metrics= ['accuracy'])

# %%
history = model.fit(train_datagen, epochs = 10, validation_data=test_datagen)
# Out:
# Epoch 1/10
# D:\Program_part\anaconda\New_folder\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1169s 4s/step - accuracy: 0.6942 - loss: 0.6679 - val_accuracy: 0.9222 - val_loss: 0.2125
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1059s 3s/step - accuracy: 0.9453 - loss: 0.1633 - val_accuracy: 0.9620 - val_loss: 0.1123
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1055s 3s/step - accuracy: 0.9612 - loss: 0.1172 - val_accuracy: 0.9806 - val_loss: 0.0685
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1056s 3s/step - accuracy: 0.9632 - loss: 0.0946 - val_accuracy: 0.9861 - val_loss: 0.0424
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1072s 3s/step - accuracy: 0.9814 - loss: 0.0522 - val_accuracy: 0.9796 - val_loss: 0.0493
# Epoch 6/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 940s 3s/step - accuracy: 0.9822 - loss: 0.0512 - val_accuracy: 0.9898 - val_loss: 0.0287
# Epoch 7/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1086s 4s/step - accuracy: 0.9869 - loss: 0.0361 - val_accuracy: 0.9889 - val_loss: 0.0336
# Epoch 8/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1093s 4s/step - accuracy: 0.9848 - loss: 0.0408 - val_accuracy: 0.9935 - val_loss: 0.0176
# Epoch 9/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1100s 4s/step - accuracy: 0.9942 - loss: 0.0193 - val_accuracy: 0.9889 - val_loss: 0.0293
# Epoch 10/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1109s 4s/step - accuracy: 0.9902 - loss: 0.0244 - val_accuracy: 0.9870 - val_loss: 0.0410

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
EPOCHS=10
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Accuracy')
plt.plot(range(EPOCHS), val_loss, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
